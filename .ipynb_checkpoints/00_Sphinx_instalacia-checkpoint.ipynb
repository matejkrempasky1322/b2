# %% [markdown]
# # Inštalácia Sphinx
#
# Sphinx je multiplatformová aplikácia vytvorená v jazyku Python. Inštalácia pre rôzne platformy je popísaná v [dokumentácii](https://www.sphinx-doc.org/en/master/usage/installation.html). Prehliadanie publikácií vytvorených pomocou Sphinx nevyžaduje okrem štandardného www prehliadača inštaláciu doplnkového programového vybavenia.
#
# ## Linux
#
# Pre distribúciu Debian/Ubuntu môžeme nainštalovať globálnu verziu Sphinx pomocou inštalátora apt-get:

# %%
apt-get install python3-sphinx

# %% [markdown]
# alebo z [Python Package Index](https://pypi.org/project/Sphinx/) (PyPI) pomocou inštalátora pip:

# %%
pip install -U sphinx

# %% [markdown]
# Druhý spôsob umožňuje paralelnú inštaláciu rôznych verzií Sphinx a ich konfigurácií vo virtuálnych prostrediach vytvorených pomocou [venv](https://docs.python.org/3/library/venv.html).
#
# Aktuálnu verziu Sphinx získame pomocou príkazu:

# %%
sphinx-build --version

# %% [markdown]
# Nainštalovaná verzia Sphinx konvertuje texty vytvorené vo formáte reStructuredText. Pre tvorbu publikácií v značkovacom jazyku Markdown doinštalujeme prekladač MyST, popis inštalácie je v [dokumentácii](https://myst-parser.readthedocs.io/en/latest/intro.html):

# %%
pip install myst-parser
# Out:
# Requirement already satisfied: myst-parser in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.0.1)
# Requirement already satisfied: docutils<0.22,>=0.18 in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from myst-parser) (0.21.2)
# Requirement already satisfied: jinja2 in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from myst-parser) (3.1.6)
# Requirement already satisfied: markdown-it-py~=3.0 in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from myst-parser) (3.0.0)
# Requirement already satisfied: mdit-py-plugins~=0.4 in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from myst-parser) (0.5.0)
# Requirement already satisfied: pyyaml in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from myst-parser) (6.0.3)
# Requirement already satisfied: sphinx<8,>=6 in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from myst-parser) (7.4.7)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from markdown-it-py~=3.0->myst-parser) (0.1.2)
# Requirement already satisfied: sphinxcontrib-applehelp in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sphinx<8,>=6->myst-parser) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sphinx<8,>=6->myst-parser) (2.0.0)
# Requirement already satisfied: sphinxcontrib-jsmath in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sphinx<8,>=6->myst-parser) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sphinx<8,>=6->myst-parser) (2.1.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sphinx<8,>=6->myst-parser) (2.0.0)
# Requirement already satisfied: sphinxcontrib-qthelp in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sphinx<8,>=6->myst-parser) (2.0.0)
# Requirement already satisfied: Pygments>=2.17 in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sphinx<8,>=6->myst-parser) (2.20.0)
# Requirement already satisfied: snowballstemmer>=2.2 in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sphinx<8,>=6->myst-parser) (3.0.1)
# Requirement already satisfied: babel>=2.13 in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sphinx<8,>=6->myst-parser) (2.18.0)
# Requirement already satisfied: alabaster~=0.7.14 in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sphinx<8,>=6->myst-parser) (0.7.16)
# Requirement already satisfied: imagesize>=1.3 in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sphinx<8,>=6->myst-parser) (2.0.0)
# Requirement already satisfied: requests>=2.30.0 in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sphinx<8,>=6->myst-parser) (2.33.1)
# Requirement already satisfied: packaging>=23.0 in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sphinx<8,>=6->myst-parser) (26.2)
# Requirement already satisfied: colorama>=0.4.6 in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sphinx<8,>=6->myst-parser) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jinja2->myst-parser) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.30.0->sphinx<8,>=6->myst-parser) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.30.0->sphinx<8,>=6->myst-parser) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.30.0->sphinx<8,>=6->myst-parser) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\matej\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.30.0->sphinx<8,>=6->myst-parser) (2026.4.22)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Windows
#
# Python nie je štandardnou súčasťou distribúcie Windows, pre jeho inštaláciu využite návody dostupné na internete, napríklad [The Hitchhiker's Guide to Python](https://docs.python-guide.org/). Doporučená verzia pre inštaláciu je Python 3. Po inštalácii nainštalujte Sphinx pomocou inštalátora pip.
